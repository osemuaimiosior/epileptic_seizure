# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier

import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data.csv')
df = data.copy()

# %%
pd.options.display.max_columns=None

# %%
df.head()
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  X11  X12  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  -38  -10   35
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  232  237  258
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  -99  -94
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  -72  -68
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  -90 -103
#
#    X13  X14  X15  X16  X17   X18   X19   X20  X21  X22  X23  X24  X25  X26  \
# 0   64  113  152  164  127    50   -47  -121 -138 -125 -101  -50   11   39
# 1  212    2 -267 -605 -850 -1001 -1109 -1090 -967 -746 -464 -152  118  318
# 2  -96 -104 -103  -92  -75   -69   -69   -53  -37  -14  -10  -39  -78 -102
# 3  -74  -80  -83  -73  -68   -61   -58   -59  -64  -79  -84  -97  -94  -84
# 4  -84  -43   -9    3  -21   -60   -96  -103  -75  -29   14   55   78   73
#
# ...

# %%
data.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
df=df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  X11  X12  X13  X14  X15  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  -10   35   64  113  152
# 1  386  382  356  331  320  315  307  272  244  232  237  258  212    2 -267
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  -99  -94  -96 -104 -103
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  -72  -68  -74  -80  -83
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  -90 -103  -84  -43   -9
#
#    X16  X17   X18   X19   X20  X21  X22  X23  X24  X25  X26  X27  X28  X29  \
# 0  164  127    50   -47  -121 -138 -125 -101  -50   11   39   24   48   64
# 1 -605 -850 -1001 -1109 -1090 -967 -746 -464 -152  118  318  427  473  485
# 2  -92  -75   -69   -69   -53  -37  -14  -10  -39  -78 -102  -98  -80  -54
# 3  -73  -68   -61   -58   -59  -64  -79  -84  -97  -94  -84  -77  -75  -72
# 4    3  -21   -60   -96  -103  -75  -29   14   55   78   73   28  -13  -43
#
# ...

# %%
siezure = df.groupby(['y']).mean()

# %%
siezure
# Out:
#           X1         X2         X3         X4         X5         X6  \
# y
# 1 -21.936522 -19.049130 -15.293913  -9.836087  -3.707391   2.730000
# 2  -7.710000  -8.148696  -8.020000  -8.050435  -7.776957  -8.220870
# 3  -9.207391  -9.276522  -9.968261 -10.634348 -11.172174 -11.559130
# 4 -12.726087 -12.410435 -12.272609 -12.096957 -12.083043 -12.349130
# 5  -6.326957  -5.673043  -5.380870  -5.097391  -5.309130  -5.618261
#
#           X7         X8         X9        X10        X11        X12  \
# y
# 1   6.899565   7.425652   8.380870  10.773913  12.320870  10.595652
# 2  -8.597826  -9.210000  -9.217826  -9.347826  -8.891304  -8.424783
# 3 -11.797826 -12.013043 -12.132609 -12.249130 -12.280000 -11.983478
# 4 -13.064348 -13.419565 -13.441739 -13.147826 -13.143478 -13.242609
# 5  -5.950000  -6.218696  -6.378696  -6.871304  -7.143478  -7.155652
#
#          X13        X14        X15        X16        X17        X18  \
# y
# ...

# %%
one = siezure.iloc[:1,:].transpose()
one.plot(figsize=(8,5),color='Brown')

# %%
five = siezure.iloc[4:5,:].transpose()
five.plot(figsize=(8,5))

# %%
four = siezure.iloc[3:4,:].transpose()
four.plot(figsize=(8,5), color='orange')

# %%
three = siezure.iloc[2:3,:].transpose()
three.plot(figsize=(8,5),color= 'black')

# %%
two = siezure.iloc[1:2,:].transpose()
two.plot(figsize=(8,5), color='gold')

# %%
y= df.y
y = pd.get_dummies(y)

# %%
df = pd.concat([df, y], axis=1)

# %%
df = df.drop('y', axis=1)
df.head()
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  X11  X12  X13  X14  X15  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  -10   35   64  113  152
# 1  386  382  356  331  320  315  307  272  244  232  237  258  212    2 -267
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  -99  -94  -96 -104 -103
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  -72  -68  -74  -80  -83
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  -90 -103  -84  -43   -9
#
#    X16  X17   X18   X19   X20  X21  X22  X23  X24  X25  X26  X27  X28  X29  \
# 0  164  127    50   -47  -121 -138 -125 -101  -50   11   39   24   48   64
# 1 -605 -850 -1001 -1109 -1090 -967 -746 -464 -152  118  318  427  473  485
# 2  -92  -75   -69   -69   -53  -37  -14  -10  -39  -78 -102  -98  -80  -54
# 3  -73  -68   -61   -58   -59  -64  -79  -84  -97  -94  -84  -77  -75  -72
# 4    3  -21   -60   -96  -103  -75  -29   14   55   78   73   28  -13  -43
#
# ...

# %%
clean_df = df.copy()

# %%
featuers = clean_df.iloc[:,:-5]
target = clean_df.iloc[:, -5:]

# %%
scaler = StandardScaler()
featuers_std = scaler.fit_transform(featuers)

# %%
x_train,x_test,y_train,y_test = train_test_split(featuers_std, target,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier().fit(x_train, y_train)

# %%
y_pred = clf.predict(x_test)

# %%
cross_score = cross_val_score(clf,y_test,y_pred, cv=5)

# %%
print(cross_score)
print('mean: ',np.mean(cross_score))
# Out:
# [0.76347826 0.78782609 0.74782609 0.77565217 0.79304348]
# mean:  0.7735652173913043

# %%
pickle.dump(clf, open ('clf.pickle', 'wb'))

# %%
pickle.dump(scaler, open ('scaler.pickle', 'wb'))
